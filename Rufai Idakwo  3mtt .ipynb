# %% [markdown]
# # DATA SCIENCE CLASS TEST

# %% [markdown]
# # NAME: RUFAI IDAKWO

# %% [markdown]
# # PHONE NUMBER: 08138805134

# %% [markdown]
# # EMAIL ADDRESS : idakworufai2019@gmail.com

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Bio = {"Name":["Kebiru","Aminu","Kolapo","Adeola","Junai","Seyi","Segun","Israel","Fasure","Lola"],
     "Age":[45, 65, 70, 65, 76, 89, 45, 85, 90, 45],
     "Sex":["Male","Male","Female","Female","Female","Female","Male","Male","Male","Male"]}

# %%
df = pd.DataFrame(Bio)

# %%
df
# Out:
#      Name  Age     Sex
# 0  Kebiru   45    Male
# 1   Aminu   65    Male
# 2  Kolapo   70  Female
# 3  Adeola   65  Female
# 4   Junai   76  Female
# 5    Seyi   89  Female
# 6   Segun   45    Male
# 7  Israel   85    Male
# 8  Fasure   90    Male
# 9    Lola   45    Male

# %%
df["Name"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Name'>

# %%
{df["Age"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
df["Sex"].value_counts().plot(kind="line")
# Out:
# <Axes: xlabel='Sex'>

# %% [markdown]
# # What is Data Science

# %% [markdown]
# # Data Science is the study of data to extract maeningful insight for business. It is multidisciplinary approach that combines principles and practices from the fields of mathematics, statistics, and computer engineering to analyze large amount of data.

# %% [markdown]
# # What is Data Analysis

# %% [markdown]
# Data analysis is the process of cleaning, analyzing, interpreting, and vitualizing data using various techniques and business intelligence tools.

# %% [markdown]
# # lIFECYCLE OF DATA SCIENCE

# %%
#1. IDENTIFY PROBLEM
#2. COLLECT DATA
#3. DATA CLEANING
#4. DATA ANALYSIS
#5. DATA MODELING
#6. MODEL DEVELOPMENT

# %% [markdown]
# # TOOLS USED IN DATA SCIENCE

# %%
#1. PYTHON 
#2. JUPITER NOTEBOOK
#3. EXCEL
#4. GOOGLE COLAB
